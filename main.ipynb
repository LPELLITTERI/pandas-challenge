# %%
import os
import pandas as pd
import numpy as np

# %%
#Dependencies
import pandas as pd

#File path
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)


# Combine the data into a single dataset.  
school_data_total = pd.merge(student_data, school_data, how="left", on = ["school_name","school_name"])
school_data_total.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#total number of uniques schools
school_total_unique = school_data_total['school_name'].unique()
print(school_total_unique)
# Out:
# ['Huang High School' 'Figueroa High School' 'Shelton High School'
#  'Hernandez High School' 'Griffin High School' 'Wilson High School'
#  'Cabrera High School' 'Bailey High School' 'Holden High School'
#  'Pena High School' 'Wright High School' 'Rodriguez High School'
#  'Johnson High School' 'Ford High School' 'Thomas High School']

# %%
school_total_unique = []
school_total = []
total_students = []
total_budget = []
average_math_score = []
average_reading_score = []
avg_pass_math = []
avg_pass_read = []
pass_math_reading_count = []
school_types = []
student_count = []
per_school_capita = []
overall_passing_rate = []
school_name = []

# %%
#calculate total number unique schools
school_total_unique = len(school_data_total["school_name"].unique())
school_total_unique
# Out:
# 15

# %%
school_total = school_data_total['School ID'].count()
print(school_total)
# Out:
# 39170

# %%
#total number of students
total_students = school_data_total['student_name'].count()
print(total_students)
# Out:
# 39170

# %%
#calculate total budget for schools
total_budget = school_data['budget'].sum()
print(total_budget )
# Out:
# 24649428

# %%
# calculate avg math score 
average_math_score = school_data_total['math_score'].mean()
print(average_math_score)
# Out:
# 78.98537145774827

# %%
#calculate avg reading score 
average_reading_score = school_data_total['reading_score'].mean()
print(average_reading_score)
# Out:
# 81.87784018381414

# %%
#percentage passing math
avg_math_score = school_data_total.loc[school_data_total['math_score'] >= 70]
avg_pass_math = len(avg_math_score)/ total_students * 100
print(avg_pass_math)
# Out:
# 74.9808526933878

# %%
#percentage passing reading
avg_reading_score = school_data_total.loc[school_data_total['reading_score'] >= 70]
avg_pass_read = len(avg_reading_score)/ total_students * 100
print(avg_pass_read)
# Out:
# 85.80546336482001

# %%
 #calculate overall pass score math/read
pass_math_reading_count = school_data_total[
    (school_data_total["math_score"] >= 70) & (school_data_total["reading_score"] >= 70)
].count()["student_name"]
overall_pass = pass_math_reading_count /  float(total_students) * 100
overall_pass
# Out:
# 65.17232575950983

# %%
#create dataframe for district summary
district_summary = {
                                "Total Schools": [school_total_unique],
                                "Total Students": [total_students],
                                "Total Budget": [total_budget],
                                "Average Math Score": [average_math_score],
                                "Average Reading Score": [average_reading_score],
                                "% Passing Math": [avg_pass_math],
                                "% Passing Reading": [avg_pass_read,]
                                                                    
                    }
district_summary = pd.DataFrame(district_summary)
#Reorganize columns with double brackets
#district_summary = district_summary["Total Schools", "Total Students", "Total Budget", 
                                     #"Average Math Score", "Average Reading Score", 
                                     #""% Passing Math", "% Passing Reading"]

# Format to "$0,000.00"
district_summary['Total Budget'] = district_summary['Total Budget'].map('${:,.2f}'.format)

district_summary
# Out:
#    Total Schools  Total Students    Total Budget  Average Math Score  \
# 0             15           39170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading
# 0               81.87784       74.980853          85.805463

# %% [markdown]
# avg_reading_scores = school_data_total.groupby("school_name").mean()["reading_score"]
# avg_math_scores = school_data_total.groupby("school_name").mean()["math_score"]
# total_budget_by_school = school_data_total.groupby("school_name").mean()["budget"]
# school_type = school_data_total.groupby("type")
# pd.DataFrame([avg_reading_scores, avg_math_scores, total_budget_by_school]).transpose()

# %%
#agg function create data with function inside table

# %% [markdown]
# # School Summary

# %%
#select school type
school_types = school_data.set_index(["school_name"])["type"]
school_types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
#calculate student count
student_count = school_data_total.groupby("school_name")["student_name"].count()
student_count
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: student_name, dtype: int64

# %%
#calculate per capita budget

per_school_budget = school_data_total.groupby(["school_name"]).mean()["budget"]
per_school_capita = per_school_budget / student_count
                                                      
per_school_capita
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#calculate average test scores
per_school_math  = school_data_total.groupby('school_name').agg({'math_score':'mean'})
per_school_math
# Out:
#                        math_score
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Ford High School        77.102592
# Griffin High School     83.351499
# Hernandez High School   77.289752
# Holden High School      83.803279
# Huang High School       76.629414
# Johnson High School     77.072464
# Pena High School        83.839917
# Rodriguez High School   76.842711
# Shelton High School     83.359455
# Thomas High School      83.418349
# Wilson High School      83.274201
# Wright High School      83.682222

# %%
#calculate average test scores
per_school_reading  = school_data_total.groupby('school_name').agg({'reading_score':'mean'})
per_school_reading
# Out:
#                        reading_score
# school_name
# Bailey High School         81.033963
# Cabrera High School        83.975780
# Figueroa High School       81.158020
# Ford High School           80.746258
# Griffin High School        83.816757
# Hernandez High School      80.934412
# Holden High School         83.814988
# Huang High School          81.182722
# Johnson High School        80.966394
# Pena High School           84.044699
# Rodriguez High School      80.744686
# Shelton High School        83.725724
# Thomas High School         83.848930
# Wilson High School         83.989488
# Wright High School         83.955000

# %%
#calculate number of schools with a math score 70 or higher
school_passing_math = school_data_total.loc[school_data_total["math_score"] >= 70].nunique()["school_name"]
school_passing_math
# Out:
# 15

# %%
#calculate number of schools with a reading score 70 or higher
school_passing_reading = school_data_total.loc[school_data_total["reading_score"] >= 70].nunique()["school_name"]
school_passing_reading
# Out:
# 15

# %%
#passed both math and reading
passing_math_and_reading = school_data_total[
    (school_data_total["reading_score"] >= 70) & (school_data_total["ma
                                                                    th_score"] >= 70)
]
passing_math_and_reading
# Out:
#   File "/var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_6985/3657138247.py", line 3
#     (school_data_total["reading_score"] >= 70) & (school_data_total["ma
#                                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
#calculate passing rates


per_school_passing_math = school_passing_math / student_count * 100
per_school_passing_reading = school_passing_reading / student_count * 100
overall_passing_rate = passing_math_and_reading.nunique()["school_name"] / student_count * 100
overall_passing_rate
# Out:
# school_name
# Bailey High School       0.301447
# Cabrera High School      0.807320
# Figueroa High School     0.508647
# Ford High School         0.547645
# Griffin High School      1.021798
# Hernandez High School    0.323625
# Holden High School       3.512881
# Huang High School        0.514227
# Johnson High School      0.315060
# Pena High School         1.559252
# Rodriguez High School    0.375094
# Shelton High School      0.851789
# Thomas High School       0.917431
# Wilson High School       0.657030
# Wright High School       0.833333
# Name: student_name, dtype: float64

# %%
#dictionary to hold results
per_school_summary = pd.DataFrame({#"School Name" : school_name,
                     "School Type" : school_types,
                      "Total Students": total_students,
                      "Total School Budget": total_budget,
                      "Per Student Budget" : per_school_capita,
                      "Average Math Score": average_math_score,
                      "Average Reading Score": average_reading_score,
                      "% Passing Math": avg_pass_math,
                      "% Passing Reading": avg_pass_read,
                      "% Overall Pass Rate": overall_passing_rate})
                                
    
#Create DataFrame
#per_school_summary = pd.DataFrame(school_summary_dict)
    
    
# #per_school_summary.groupby("school_name").agg({"School Type" : school_types,
#                       "Total Students": total_students,
#                       "Total School Budget": total_budget,
#                       "Per Student Budget" : per_school_capita,
#                       "Average Math Score": average_math_score,
#                       "Average Reading Score": average_reading_score,
#                       "% Passing Math": avg_pass_math,
#                       "% Passing Reading": avg_pass_read,
#                       "% Overall Pass Rate": overall_passing_rate,})
    
#Reorganize columns with double brackets
#per_school_summary = school_data_total.copy()
#per_school_summary.index.name = "School Name"
#per_school_summary["Total School Budget"] = per_school_summary["Total School Budget"].map("${:,.}".format)
#per_school_summary["Per Student Budget"] = per_school_summary["Per Student Budget"].map("${:,.}".format)

per_school_summary
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District           39170             24649428
# Cabrera High School       Charter           39170             24649428
# Figueroa High School     District           39170             24649428
# Ford High School         District           39170             24649428
# Griffin High School       Charter           39170             24649428
# Hernandez High School    District           39170             24649428
# Holden High School        Charter           39170             24649428
# Huang High School        District           39170             24649428
# Johnson High School      District           39170             24649428
# Pena High School          Charter           39170             24649428
# Rodriguez High School    District           39170             24649428
# Shelton High School       Charter           39170             24649428
# ...

# %% [markdown]
# #

# %% [markdown]
# # Highest Performing Schools (by Overall Passing)

# %%
#Sort the schools by % Overall Passing in descending order and display the top 5 rows.
#Save the results in a DataFrame called "top_schools".

top_schools = per_school_summary.sort_values("% Overall Pass Rate", ascending=False) 
top_schools.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Holden High School      Charter           39170             24649428
# Pena High School        Charter           39170             24649428
# Griffin High School     Charter           39170             24649428
# Thomas High School      Charter           39170             24649428
# Shelton High School     Charter           39170             24649428
#
#                      Per Student Budget  Average Math Score  \
# Holden High School                581.0           78.985371
# Pena High School                  609.0           78.985371
# Griffin High School               625.0           78.985371
# Thomas High School                638.0           78.985371
# Shelton High School               600.0           78.985371
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Holden High School                81.87784       74.980853          85.805463
# ...

# %% [markdown]
# # Bottom Performing Schools (By % Overall Passing)

# %%
#Sort the schools by % Overall Passing in ascending order and display the top 5 rows.
#Save the results in a DataFrame called "bottom_perform".

bottom_perform = per_school_summary.sort_values("% Overall Pass Rate", ascending=True) 
bottom_perform.head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District           39170             24649428
# Johnson High School      District           39170             24649428
# Hernandez High School    District           39170             24649428
# Rodriguez High School    District           39170             24649428
# Figueroa High School     District           39170             24649428
#
#                        Per Student Budget  Average Math Score  \
# Bailey High School                  628.0           78.985371
# Johnson High School                 650.0           78.985371
# Hernandez High School               652.0           78.985371
# Rodriguez High School               637.0           78.985371
# Figueroa High School                639.0           78.985371
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                  81.87784       74.980853
# ...

# %% [markdown]
# # Scores by Grade

# %%
# Use the code provided to separate the data by grade
nineth = school_data_total[(school_data_total["grade"] == "9th")]
tenth = school_data_total[(school_data_total["grade"] == "10th")]
eleventh = school_data_total[(school_data_total["grade"] == "11th")]
twelveth = school_data_total[(school_data_total["grade"] == "12th")]

# Group each garde by "school_name" 
nineth_grouped = nineth.groupby(["school_name"])
tenth_grouped = tenth.groupby(["school_name"])
eleventh_grouped = eleventh.groupby(["school_name"])
twelveth_grouped =
# Out:
#   File "/var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_6985/418129174.py", line 11
#     twelveth_grouped =
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Math Scores by Grade

# %%
# Average Math Scores by Grade
math_nineth_mean = nineth_grouped['math_score'].mean()
math_tenth_mean = tenth_grouped['math_score'].mean()
math_eleventh_mean = eleventh_grouped['math_score'].mean()
math_twelveth_mean = twelveth_grouped['math_score'].mean()

# Creating dictionary holding the results 
math_by_grade = {
    '9th': math_nineth_mean,
    '10th': math_tenth_mean,
    '11th': math_eleventh_mean,
    '12th': math_twelveth_mean
}
# # Use the code to select only the `math_score`.
# ninth_grade_math_scores = ninth_graders_scores.mean["math_score"]
# tenth_grader_math_scores = tenth_graders_scores.mean["math_score"]
# eleventh_grader_math_scores = eleventh_graders_scores.mean["math_score"]
# twelfth_grader_math_scores = twelfth_graders_scores.mean["math_score"]

# Combine each of the scores above into single DataFrame called `math_scores_by_grade`
math_scores_by_grade = pd.DataFrame(math_by_grade)

# Minor data wrangling
math_scores_by_grade.index.name = None

# Display the DataFrame
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# # Reading Scores By Grade

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_total[(school_data_total["grade"] == "9th")]
tenth_graders = school_data_total[(school_data_total["grade"] == "10th")]
eleventh_graders = school_data_total[(school_data_total["grade"] == "11th")]
twelfth_graders = school_data_total[(school_data_total["grade"] == "12th")]

# Group by "school_name" and take the mean of each.
ninth_graders_scores = nineth.groupby(["school_name"])
tenth_graders_scores = tenth.groupby(["school_name"])
eleventh_graders_scores = eleventh.groupby(["school_name"])
twelfth_graders_scores = twelveth.groupby(["school_name"])

# Use the code to select only the `reading_score`.
ninth_grade_reading_scores = ninth_graders_scores["reading_score"]
tenth_grader_reading_scores = tenth_graders_scores["reading_score"]
eleventh_grader_reading_scores = eleventh_graders_scores.mean()["reading_score"]
twelfth_grader_reading_scores = twelfth_graders_scores["reading_score"]


# Creating dictionary holding the results 
reading_by_grade = {
    '9th': math_nineth_mean,
    '10th': math_tenth_mean,
    '11th': math_eleventh_mean,
    '12th': math_twelveth_mean
}
# Combine each of the scores above into single DataFrame called `reading_scores_by_grade`
reading_scores_by_grade = pd.DataFrame(reading_by_grade)

# Minor data wrangling
reading_scores_by_grade = reading_scores_by_grade[["9th", "10th", "11th", "12th"]]
reading_scores_by_grade.index.name = None

# Display the DataFrame
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# # Scores By School Spending

# %%
# Establish the bins 
spending_bins = [0, 585, 630, 645, 680]

spending_group_name = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
# Create a copy of the school summary since it has the "Per Student Budget" 
school_spending_df = per_school_summary.copy()
school_spending_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District           39170             24649428
# Cabrera High School       Charter           39170             24649428
# Figueroa High School     District           39170             24649428
# Ford High School         District           39170             24649428
# Griffin High School       Charter           39170             24649428
# Hernandez High School    District           39170             24649428
# Holden High School        Charter           39170             24649428
# Huang High School        District           39170             24649428
# Johnson High School      District           39170             24649428
# Pena High School          Charter           39170             24649428
# Rodriguez High School    District           39170             24649428
# Shelton High School       Charter           39170             24649428
# ...

# %%
# Use `pd.cut` to categorize spending based on the bins.
school_spending_df["Spending Ranges(Per Student)"] = pd.cut(school_spending_df["Per Student Budget"],
                                                             spending_bins,
                                                             labels=spending_group_name,
                                                            include_lowest=True)



# Grouping dataframe based on Spending Ranges (Per Student)
school_spending_grouped = school_spending_df.groupby(['Spending Ranges (Per Student)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_6985/2914266908.py in <module>
#       8
#       9 # Grouping dataframe based on Spending Ranges (Per Student)
# ---> 10 school_spending_grouped = school_spending_df.groupby(['Spending Ranges (Per Student)'])
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
# ...

# %%
#  Calculate averages for the desired columns. 
spending_math_scores = school_spending_df.groupby(["Spending Ranges(Per Student)"]).mean()["Average Math Score"]
spending_reading_scores = school_spending_df.groupby(["Spending Ranges(Per Student)"]).mean()["Average Reading Score"]
spending_passing_math = school_spending_df.groupby(["Spending Ranges(Per Student)"]).mean()["% Passing Math"]
spending_passing_reading = school_spending_df.groupby(["Spending Ranges(Per Student)"]).mean()["% Passing Reading"]
overall_passing_spending = school_spending_df.groupby(["Spending Ranges(Per Student)"]).mean()["% Overall Pass Rate"]

# Create the dictionary to hold the results
scores_by_school_spending_dict = {
    'Average Math Score': spending_math_scores,
    'Average Reading Score': spending_reading_scores,
    '% Passing Math': spending_passing_math,
    '% Passing Reading': spending_passing_reading,
    '% Overall Passing': overall_passing_spending
}

# %%
# Assemble into DataFrame
spending_summary = pd.DataFrame(scores_by_school_spending_dict)

# Display results
spending_summary
# Out:
#                               Average Math Score  Average Reading Score  \
# Spending Ranges(Per Student)
# <$585                                  78.985371               81.87784
# $585-630                               78.985371               81.87784
# $630-645                               78.985371               81.87784
# $645-680                               78.985371               81.87784
#
#                               % Passing Math  % Passing Reading  \
# Spending Ranges(Per Student)
# <$585                              74.980853          85.805463
# $585-630                           74.980853          85.805463
# $630-645                           74.980853          85.805463
# $645-680                           74.980853          85.805463
#
#                               % Overall Passing
# Spending Ranges(Per Student)
# <$585                                  1.452641
# $585-630                               0.933571
# ...

# %% [markdown]
# # Scores by School Size

# %% [markdown]
# # Scores by School Size

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
school_size = ["Small(<1000)", "Medium(1000-2000)", "Large(2000-5000)"]

# %%
# Categorize the spending based on the bins
# Use `pd.cut` on the "Total Students" column of the `per_school_summary` DataFrame.

per_school_summary["School Size"] = pd.cut(per_school_summary["Total Students"],
                                                             size_bins,
                                                             labels=school_size,)

size_summary = per_school_summary.groupby("School Size")
size_summary = size_summary[["Average Math Score", "Average Reading Score", "% Passing Math", 
                             "% Passing Reading", "% Overall Pass Rate"]]



per_school_summary.mean()
# Out:
# Total Students           3.917000e+04
# Total School Budget      2.464943e+07
# Per Student Budget       6.200667e+02
# Average Math Score       7.898537e+01
# Average Reading Score    8.187784e+01
# % Passing Math           7.498085e+01
# % Passing Reading        8.580546e+01
# % Overall Pass Rate      8.697719e-01
# School Size                       NaN
# dtype: float64

# %%
# Calculate averages for the desired columns. 
size_math_scores = per_school_summary.groupby(["School Size"]).mean()["Average Math Score"]
size_reading_scores = per_school_summary.groupby(["School Size"]).mean()["Average Reading Score"]
size_passing_math = per_school_summary.groupby(["School Size"]).mean()["% Passing Math"]
size_passing_reading = per_school_summary.groupby(["School Size"]).mean()["% Passing Reading"]
size_overall_passing = per_school_summary.groupby(["School Size"]).mean()["% Overall Pass Rate"]

# %%
# Create a DataFrame called `size_summary` that breaks down school performance based on school size (small, medium, or large).
# Use the scores above to create a new DataFrame called `size_summary`Display results 

size_summary_dict = {
    'Average Math Score': size_math_scores,
    'Average Reading Score': size_reading_scores,
    '% Passing Math': size_passing_math,
    '% Passing Reading': size_passing_reading,
    '% Overall Pass Rate': size_overall_passing
}

size_summary = pd.DataFrame(size_summary_dict)

size_summary
# Out:
#                    Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small(<1000)                      NaN                    NaN             NaN
# Medium(1000-2000)                 NaN                    NaN             NaN
# Large(2000-5000)                  NaN                    NaN             NaN
#
#                    % Passing Reading  % Overall Pass Rate
# School Size
# Small(<1000)                     NaN                  NaN
# Medium(1000-2000)                NaN                  NaN
# Large(2000-5000)                 NaN                  NaN

# %% [markdown]
# # Scores by School Type

# %%
# Group the per_school_summary DataFrame by "School Type" and average the results.
type_math_scores = per_school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_reading_scores = per_school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_passing_math = per_school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_passing_reading = per_school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_overall_passing = per_school_summary.groupby(["School Type"]).mean()["Average Math Score"]

# Use the code provided to select new column data
average_math_score_by_type = type_math_scores["Average Math Score"]
average_reading_score_by_type = type_reading_scores["Average Reading Score"]
average_percent_passing_math_by_type = type_passing_math["% Passing Math"]
average_percent_passing_reading_by_type = type_passing_reading["% Passing Reading"]
average_percent_overall_passing_by_type = type_overall_passing["% Overall Pass Rate"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4409             try:
# -> 4410                 return libindex.get_value_at(s, key)
#    4411             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_6985/3842456689.py in <module>
#       7
# ...

# %%
# Use the code provided to select new column data
average_math_score_by_type = type_math_scores["Average Math Score"]
average_reading_score_by_type = type_reading_scores["Average Reading Score"]
average_percent_passing_math_by_type = type_passing_math["% Passing Math"]
average_percent_passing_reading_by_type = type_passing_reading["% Passing Reading"]
average_percent_overall_passing_by_type = type_overall_passing["% Overall Passing"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4409             try:
# -> 4410                 return libindex.get_value_at(s, key)
#    4411             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_6985/3458347929.py in <module>
# ...

# %%
# Assemble the new data by type into a DataFrame called `type_summary`
type_summary = school_summary.groupby("School Type")
type_summary = type_summary[["Average Math Score", "Average Reading Score", "% Passing Math", 
                             "% Passing Reading", "% Overall Pass Rate"]

# Display results
type_summary.mean()
# Out:
#   File "/var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_6985/3058830112.py", line 7
#     type_summary.mean()
#                ^
# SyntaxError: invalid syntax
